# %%
import os
print(os.getcwd())
# Out:
# C:\Users\tejas\OneDrive\Desktop\DRG_project\notebooks

# %%
import os

print(os.path.exists(r"C:\Users\tejas\OneDrive\Desktop\DRG_project\data\raw\consumption_d.csv"))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\tejas\OneDrive\Desktop\DRG_project\data\raw\consumption_d.csv")

# %%
print(df.shape)
# Out:
# (39727, 1026)

# %%
df.head()
# Out:
#                    GMT  D0000  D0001  D0002  D0003  D0004  D0005  D0006  \
# 0  2011-11-23 09:00:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  2011-11-23 09:30:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  2011-11-23 10:00:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  2011-11-23 10:30:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4  2011-11-23 11:00:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    D0007  D0008  ...  D1015  D1016  D1017  D1018  D1019  D1020  D1021  D1022  \
# 0    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    D1023  D1024
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# ...

# %%
df.columns
# Out:
# Index(['GMT', 'D0000', 'D0001', 'D0002', 'D0003', 'D0004', 'D0005', 'D0006',
#        'D0007', 'D0008',
#        ...
#        'D1015', 'D1016', 'D1017', 'D1018', 'D1019', 'D1020', 'D1021', 'D1022',
#        'D1023', 'D1024'],
#       dtype='object', length=1026)

# %%
len(df.columns) - 1
# Out:
# 1025

# %%
df["GMT"] = pd.to_datetime(df["GMT"])

# %%
print(df["GMT"].min())
print(df["GMT"].max())
# Out:
# 2011-11-23 09:00:00
# 2014-02-28 00:00:00

# %%
df.isnull().sum()
# Out:
# GMT          0
# D0000     8791
# D0001    10039
# D0002      696
# D0003     6830
#          ...
# D1020     8130
# D1021    10857
# D1022     6924
# D1023     8741
# D1024    14694
# Length: 1026, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# D0873    23667
# D0723    22758
# D0041    22326
# D0477    21419
# D0381    16689
# D0166    16642
# D0481    16423
# D0891    16280
# D0429    16257
# D0188    16247
# D0803    16240
# D0139    16234
# D0062    16229
# D0987    16229
# D0591    16226
# D0005    16225
# D0502    16200
# D0501    16187
# D0038    16185
# D0907    16181
# dtype: int64

# %%
df.describe()
# Out:
#                        GMT         D0000         D0001         D0002  \
# count                39727  30936.000000  29688.000000  39031.000000
# mean   2013-01-10 04:30:00      0.134675      0.105008      0.417383
# min    2011-11-23 09:00:00      0.008000      0.011000      0.065000
# 25%    2012-06-17 06:45:00      0.048000      0.054000      0.133000
# 50%    2013-01-10 04:30:00      0.085000      0.086000      0.203000
# 75%    2013-08-05 02:15:00      0.180000      0.142000      0.552000
# max    2014-02-28 00:00:00      1.635000      0.958000      4.247000
# std                    NaN      0.132557      0.074955      0.445413
#
#              D0003         D0004         D0005         D0006         D0007  \
# count  32897.00000  24884.000000  23502.000000  28824.000000  32000.000000
# mean       0.19065      0.117403      0.162435      0.284623      0.163429
# min        0.00000      0.005000      0.022000      0.009000      0.019000
# ...

# %%
household_means = df.drop("GMT", axis=1).mean()

household_means.sort_values(ascending=False).head(10)
# Out:
# D0823    1.350929
# D0129    1.306292
# D0203    1.104072
# D0233    0.861974
# D0029    0.782334
# D0941    0.744041
# D0810    0.725588
# D0196    0.674072
# D0987    0.663456
# D0526    0.654576
# dtype: float64

# %%
import matplotlib.pyplot as plt

avg_demand = df.drop("GMT", axis=1).mean(axis=1)

plt.figure(figsize=(15,5))
plt.plot(df["GMT"], avg_demand)
plt.title("Average Household Demand Over Time")
plt.show()
